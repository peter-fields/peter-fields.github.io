# %% [markdown]
# # Practice Test 2: Advanced Interpretability
#
# **120-minute timer. Same rules.**
#
# **Structure:**
# - Q1: Jacobian + gradient through attention
# - Q2: Level 4 Boss - O(T) Linear Attention
# - Q3: Circuit analysis + SVD — 3 parts
# - Q4: Advanced interpretability — 4 parts, **final part intentionally very hard**

# %%
import numpy as np

def softmax(z, axis=-1):
    z = z - np.max(z, axis=axis, keepdims=True)
    e = np.exp(z)
    return e / e.sum(axis=axis, keepdims=True)

def check(name, got, expected=None, cond=None, rtol=1e-4, atol=1e-6):
    try:
        if cond is not None:
            passed = bool(cond(got))
        elif expected is not None:
            passed = np.allclose(np.array(got, dtype=float),
                                 np.array(expected, dtype=float), rtol=rtol, atol=atol)
        else:
            passed = True
        status = "PASS" if passed else "FAIL"
        print(f"  [{status}] {name}")
        if not passed and expected is not None:
            g, e = np.array(got), np.array(expected)
            print(f"         got shape {g.shape}, expected shape {e.shape}")
            if g.shape == e.shape and g.size <= 16:
                print(f"         got:      {g.ravel()}")
                print(f"         expected: {e.ravel()}")
        return passed
    except Exception as exc:
        print(f"  [ERROR] {name}: {type(exc).__name__}: {exc}")
        return False

print("Helper loaded. softmax and check() are available.")
# Out:
# Helper loaded. softmax and check() are available.

# %% [markdown]
# ## Q1: Softmax Jacobian + Gradient through Attention

# %%
def softmax(z, axis=-1):
    z = z - z.max(axis=axis, keepdims=True)
    return np.exp(z) / np.exp(z).sum(axis=axis, keepdims=True)

def softmax_jacobian(z):
    """
    Goal: Compute the Jacobian matrix of the softmax function. 
    J[i, j] = pi_i * (delta_ij - pi_j), where pi is the softmax output.
    
    Args:
        z: (n,) 1D array of raw logits.
        
    Returns:
        (n, n) Jacobian matrix.
    """
    A = softmax(z, axis=-1)
    J = np.diag(A) - np.outer(A,A)
    return J

def attention_score_gradient(Q, K, V, dL_dout):
    """
    Goal: Compute the gradient of a scalar loss L w.r.t. the pre-softmax attention 
    scores S. (S = Q @ K.T / sqrt(dk)).
    
    Args:
        Q: (T, dk) Queries.
        K: (T, dk) Keys.
        V: (T, dv) Values.
        dL_dout: (T, dv) The gradient of the loss with respect to the attention output.
        
    Returns:
        (T, T) matrix representing dL/dS.
    """
    # NTS: write out full derivative chain rule
    # check shape term by term 
    # write einsum in one go
    # should be something like dL_dout @ V term @ Jacobian
    d_k = Q.shape[-1]
    scores = np.einsum("ia,ja->ij",Q,K) / np.sqrt(d_k)
    A = softmax(scores, axis=-1)
    
    def get_J_row_i(scores,  i):
        return softmax_jacobian(scores[i,:])
    
    dLdA = dL_dout @ V.T # (T x dv)(dv x T)
    
    dLdS = A * (dLdA - (dLdA*A).sum(axis=-1, keepdims=True))
    
    return dLdS
    
    raise NotImplementedError()

# %%
print("="*50 + "\nQ1 TESTS\n" + "="*50)
z = np.array([0.5, -0.3, 1.2, 0.])
pi = softmax(z)
J = softmax_jacobian(z)
check("shape (4,4)", cond=lambda x: x.shape == (4,4), got=J)
check("diagonal: pi*(1-pi)", J.diagonal(), pi*(1-pi))
T, dk, dv = 4, 3, 5
np.random.seed(0)
Q = np.random.randn(T,dk); K = np.random.randn(T,dk)
V = np.random.randn(T,dv); dL = np.random.randn(T,dv)
dS = attention_score_gradient(Q, K, V, dL)
check("gradient shape (T,T)", cond=lambda x: x.shape == (T,T), got=dS)
# Out:
# ==================================================
# Q1 TESTS
# ==================================================
#   [PASS] shape (4,4)
#   [PASS] diagonal: pi*(1-pi)
#   [PASS] gradient shape (T,T)
# True

# %% [markdown]
# ## Q2: Level 4 Boss - O(T) Linear Attention

# %%
def linear_attention_efficient(Q, K, V):
    """
    Goal: Compute the attention output in O(T) memory and time. Standard attention 
    materializes a (T, T) matrix, which OOMs for large T. Leverage matrix associativity 
    to bypass this completely. Assume no softmax is applied.
    
    Args:
        Q: (T, dk) Queries.
        K: (T, dk) Keys.
        V: (T, dv) Values.
        
    Returns:
        (T, dv) attention output matrix.
    """
    return np.einsum("ia,ja,jb->ib", Q,K,V, optimize=True)

#     raise NotImplementedError()

# %%
print("="*50 + "\nQ2 TESTS\n" + "="*50)
T_large, dk_l, dv_l = 1000, 32, 64
np.random.seed(1)
Q_l = np.random.randn(T_large, dk_l); K_l = np.random.randn(T_large, dk_l)
V_l = np.random.randn(T_large, dv_l)
expected_out = (Q_l @ K_l.T) @ V_l
out = linear_attention_efficient(Q_l, K_l, V_l)
check("shape (T, dv)", cond=lambda x: x.shape == (T_large, dv_l), got=out)
check("matches naive (Q @ K.T) @ V", out, expected_out)
# Out:
# ==================================================
# Q2 TESTS
# ==================================================
#   [PASS] shape (T, dv)
#   [PASS] matches naive (Q @ K.T) @ V
# True

# %% [markdown]
# ## Q3: Circuit Analysis + SVD (3 Parts)

# %%
# Part 1: Compute circuit matrices
def all_circuit_matrices(W_Qs, W_Ks, W_Vs, W_Os):
    """
    Goal: Combine the projection matrices into full QK and OV circuits for every head.
    
    Args:
        W_Qs: (H, d, dk)
        W_Ks: (H, d, dk)
        W_Vs: (H, d, dv)
        W_Os: (H, dv, d)
        
    Returns:
        W_QKs: (H, d, d) The Query-Key circuits.
        W_OVs: (H, d, d) The Output-Value circuits.
    """
    # should be able to einsum for each in one line
    
    W_QKs = np.einsum( "hia,hja->hij" , W_Qs, W_Ks, optimize="optimal")
    W_OVs = np.einsum( "hia,haj->hij" , W_Vs, W_Os, optimize="optimal")

    return W_QKs, W_OVs

# Part 2: SVD
def ov_svd_analysis(W_OVs, threshold=0.9):
    """
    Goal: Perform Singular Value Decomposition on the OV matrices to find their 
    effective rank (the number of singular values needed to capture `threshold` 
    fraction of the Frobenius norm squared).
    
    Args:
        W_OVs: (H, d, d) The Output-Value circuits.
        threshold: float, default 0.9. 
        
    Returns:
        all_sv: (H, d) Singular values, sorted descending.
        eff_ranks: (H,) 1D array of integer effective ranks for each head.
    """
    H,d,_ = W_OVs.shape
    U, S, Vh = np.linalg.svd(W_OVs)
    all_sv = S
#     print(f"H,d is {(H,d)}")
#     print(f"shape of S is {S.shape}")
    S_squared_cum = np.cumsum(S, axis=-1)
    totals = S_squared_cum[:, -1]
    eff_ranks = np.zeros( (H,) , dtype= S_squared_cum.dtype)
    for h in range(H):
        eff_ranks[h] = next(i+1 for i,val in enumerate(S_squared_cum[h,:]) if val >= threshold*totals[h])
    
    
    return all_sv, eff_ranks
    
    
    
    return 
# Part 3: Specificity
def rank_by_specificity(W_OVs, threshold=0.9):
    """
    Goal: Rank heads by how "specific" their OV circuits are. A head is more specific 
    if it has a lower effective rank (i.e., it maps to a tighter subspace).
    
    Args:
        W_OVs: (H, d, d)
        threshold: float, default 0.9.
        
    Returns:
        List of H integers representing the head indices, sorted from most specific 
        (lowest effective rank) to least specific.
    """
    
    all_sv, eff_ranks = ov_svd_analysis(W_OVs, threshold=threshold)
    
    return np.argsort(eff_ranks)

# %%
print("="*50 + "\nQ3 TESTS\n" + "="*50)
H, d_test, dk, dv = 4, 8, 3, 3
W_Qs = np.random.randn(H,d_test,dk); W_Ks = np.random.randn(H,d_test,dk)
W_Vs = np.random.randn(H,d_test,dv); W_Os = np.random.randn(H,dv,d_test)
W_QKs, W_OVs = all_circuit_matrices(W_Qs, W_Ks, W_Vs, W_Os)
check("W_QKs shape (H,d,d)", cond=lambda x: x.shape == (H,d_test,d_test), got=W_QKs)
all_sv, eff_ranks = ov_svd_analysis(W_OVs)
check("sv descending per head", cond=lambda x: np.all(x[:,:-1] >= x[:,1:]), got=all_sv)
ranking = rank_by_specificity(W_OVs)
check("all heads ranked", cond=lambda r: len(r) == H, got=ranking)
# Out:
# ==================================================
# Q3 TESTS
# ==================================================
#   [PASS] W_QKs shape (H,d,d)
#   [PASS] sv descending per head
#   [PASS] all heads ranked
# True

# %% [markdown]
# ## Q4: Advanced Interpretability (4 Parts)
#
# **Complete Parts 1–3 before attempting Part 4.**

# %%
# Part 1: Entropy
def head_entropy_matrix(logits_per_layer):
    """
    Goal: Calculate the average Shannon entropy of the post-softmax attention 
    distribution to identify uniform (uninformative) heads.
    
    Args:
        logits_per_layer: list of n_layers, each containing H arrays of shape (T, T).
        
    Returns:
        (n_layers, H) array of mean entropies.
    """
    # confusing--print shapes and length at first. figure out how to index in and get T,T
    # then look at one entry of the main list. is it 3D array or another list of len H arrays of shape T,T
#     print(type(logits_per_layer))
#     print(len(logits_per_layer))
#     print(type(logits_per_layer[0]) )
#     print(len(logits_per_layer[0]))
#     print(type(logits_per_layer[0][0]) )
    
    logits_per_layer = np.array(logits_per_layer) # shape is ( n_layers, H, T, T )
#     print(logits_per_layer.shape)
    A = softmax( logits_per_layer, axis=-1)
    def shannon(A):
        return -np.sum( A * np.log(A), axis=-1 ) # ( n_l , H , T ) entropy per head in each layer across all tokens 
    
    all_ents = shannon(A)
#     print(f"shape of all ents = {all_ents.shape}")
    
    return all_ents.mean(axis=-1)


# Part 2: Induction
def score_induction_heads(weights_per_layer, n):
    """
    Goal: Score heads on how perfectly they match a classic induction head pattern.
    
    Args:
        weights_per_layer: list of n_layers, each containing H arrays of shape (2n, 2n).
        n: Sequence offset to test for induction.
        
    Returns:
        (n_layers, H) array of induction scores in [0, 1].
    """
    weights_per_layer = np.array(weights_per_layer) # shape is (L, H, T, T) where T=2n
    L,H,T,_=weights_per_layer.shape
    n=int(T/2)
    
    def get_stripe_vals_one_head(A):
        return np.array([A[n+i,i+1] for i in range(n-1)])
    
    ind_scores = np.zeros((L,H))
    
    for l in range(L):
        for h in range(H):
            A_curr = weights_per_layer[l,h,:,:]
            stripe_vals = get_stripe_vals_one_head(A_curr)
            ind_scores[l,h]=np.mean(stripe_vals)
    
    return ind_scores


# Part 3: SAE
def sae_top_k(x, W_enc, b_enc, W_dec, b_dec, k=5):
    """
    Goal: Pass residual stream activations through a Sparse Autoencoder and retrieve 
    the top-k activating features.
    
    Args:
        x: (T, d) Activations.
        W_enc: (d, dh) Encoder weights.
        b_enc: (dh,) Encoder bias.
        W_dec: (dh, d) Decoder weights.
        b_dec: (d,) Decoder bias.
        k: integer. Number of top features to return.
        
    Returns:
        recon: (T, d) Reconstructed activations.
        idx: (T, k) Integer indices of the top-k features.
        vals: (T, k) Float values of the top-k features.
        mse: float representing the Mean Squared Error of the reconstruction.
    """
    T,d = x.shape
    
    pre_acts = x @ W_enc + b_enc
    acts = np.maximum(0, pre_acts)
    
    idx_of_not_top_k = np.argsort(acts, axis=-1)[:, :-k]
    
    acts_sparse = acts.copy()
    np.put_along_axis(acts_sparse, idx_of_not_top_k, 0., axis=-1 )
    
    recon = acts_sparse @ W_dec + b_dec
    idx_top_k = np.argsort(acts, axis=-1)[:,::-1]
    idx_top_k = idx_top_k[:, :k]
    
    vals = np.take_along_axis(acts, idx_top_k, axis=-1)
    
    mse = np.mean((recon - x)**2)
    
    return recon, idx_top_k, vals, mse
    
    

# Part 4 (HARD): Self-reinforcing circuits
def find_self_reinforcing(W_OVs_L1, W_OVs_L2, W_enc, W_dec, top_k=3):
    """
    Goal: Find SAE features that are heavily self-reinforced by a virtual attention head 
    spanning two layers. A feature self-reinforces if the virtual OV matrix maps its 
    decoder direction back onto its encoder direction.
    
    Args:
        W_OVs_L1: (H1, d, d) Layer 1 OV circuits.
        W_OVs_L2: (H2, d, d) Layer 2 OV circuits.
        W_enc: (d, dh) SAE Encoder.
        W_dec: (dh, d) SAE Decoder.
        top_k: int. Number of tuples to return.
        
    Returns:
        List of top_k tuples in the format (h1, h2, feature_idx, alignment_score),
        sorted descending by the alignment_score.
    """
    raise NotImplementedError()
    
#     O ΛΣ ΣΑΡΞ

# %%
print("="*50 + "\nQ4 PART 1 TESTS — Entropy\n" + "="*50)
T, H, n_layers = 4, 2, 2
np.random.seed(7)

# Uniform logits → max entropy = log(T) for each head
uniform_logits = np.zeros((T, T))
# Peaked logits → entropy ≈ 0
peaked_logits = np.full((T, T), -100.0)
for i in range(T):
    peaked_logits[i, 0] = 100.0  # always attend to token 0

logits_per_layer = [
    [uniform_logits, peaked_logits],   # layer 0: head 0 uniform, head 1 peaked
    [np.random.randn(T, T), np.random.randn(T, T)],  # layer 1: random
]

result = head_entropy_matrix(logits_per_layer)
check("output shape (n_layers, H)", result.shape, (n_layers, H))
check("uniform head has max entropy log(T)", np.isclose(result[0, 0], np.log(T), atol=1e-4), True)
check("peaked head has near-zero entropy", result[0, 1] < 0.01, True)
check("all entropies non-negative", np.all(result >= 0), True)
check("uniform >= random (sanity)", result[0, 0] >= result[1, 0], True)

print("="*50 + "\nQ4 PART 2 TESTS — Induction Scoring\n" + "="*50)
n = 4  # sequence half-length, full seq = 2n = 8
H2 = 2

# Perfect induction head: A[n+i, i+1] = 1 for i in range(n-1)
perfect = np.zeros((2*n, 2*n))
for i in range(n - 1):
    perfect[n + i, i + 1] = 1.0

# Uniform attention
uniform_attn = np.full((2*n, 2*n), 1.0 / (2*n))

weights_per_layer = [
    [perfect, uniform_attn],
]

scores = score_induction_heads(weights_per_layer, n)
check("output shape (n_layers, H)", scores.shape, (1, H2))
check("perfect induction head scores 1.0", np.isclose(scores[0, 0], 1.0, atol=1e-4), True)
check("uniform head scores ~1/(2n)", np.isclose(scores[0, 1], 1.0 / (2*n), atol=1e-4), True)
check("scores in [0, 1]", np.all((scores >= 0) & (scores <= 1)), True)

print("="*50 + "\nQ4 PART 3 TESTS — SAE Top-k\n" + "="*50)
T3, d3, dh3, k3 = 3, 6, 16, 4
np.random.seed(13)
W_enc3 = np.random.randn(d3, dh3) * 0.3
b_enc3 = np.zeros(dh3)
W_dec3 = np.random.randn(dh3, d3) * 0.3
b_dec3 = np.zeros(d3)
x3 = np.random.randn(T3, d3)

recon, idx, vals, mse = sae_top_k(x3, W_enc3, b_enc3, W_dec3, b_dec3, k=k3)

check("recon shape (T, d)", recon.shape, (T3, d3))
check("idx shape (T, k)", idx.shape, (T3, k3))
check("vals shape (T, k)", vals.shape, (T3, k3))
check("mse is scalar float", np.isscalar(mse) or mse.ndim == 0, True)
check("mse non-negative", mse >= 0, True)
check("vals all non-negative (ReLU)", np.all(vals >= 0), True)
check("idx values in [0, dh)", np.all((idx >= 0) & (idx < dh3)), True)
# vals should be sorted descending per row
check("vals sorted descending per row", np.all(vals[:, :-1] >= vals[:, 1:]), True)

# Planted feature test: one feature dominates
W_enc_p = np.zeros((d3, dh3))
W_dec_p = np.zeros((dh3, d3))
feat_dir = np.ones(d3) / np.sqrt(d3)
W_enc_p[:, 0] = feat_dir * 10   # feature 0 fires strongly
W_dec_p[0, :] = feat_dir
x_p = np.outer(np.ones(T3), feat_dir)   # input aligned with feature
recon_p, idx_p, vals_p, mse_p = sae_top_k(x_p, W_enc_p, np.zeros(dh3), W_dec_p, np.zeros(d3), k=k3)
check("planted feature 0 is top for all tokens", np.all(idx_p[:, 0] == 0), True)
# Out:
# ==================================================
# Q4 PART 1 TESTS — Entropy
# ==================================================
#   [PASS] output shape (n_layers, H)
#   [PASS] uniform head has max entropy log(T)
#   [PASS] peaked head has near-zero entropy
#   [PASS] all entropies non-negative
#   [PASS] uniform >= random (sanity)
# ==================================================
# Q4 PART 2 TESTS — Induction Scoring
# ==================================================
#   [PASS] output shape (n_layers, H)
#   [PASS] perfect induction head scores 1.0
#   [PASS] uniform head scores ~1/(2n)
#   [PASS] scores in [0, 1]
# ==================================================
# Q4 PART 3 TESTS — SAE Top-k
# ==================================================
#   [PASS] recon shape (T, d)
#   [PASS] idx shape (T, k)
#   [PASS] vals shape (T, k)
#   [PASS] mse is scalar float
#   [PASS] mse non-negative
#   [PASS] vals all non-negative (ReLU)
#   [PASS] idx values in [0, dh)
#   [PASS] vals sorted descending per row
#   [PASS] planted feature 0 is top for all tokens
# True

# %%
print("="*50 + "\nQ4 PART 4 TESTS (HARD)\n" + "="*50)
H1, H2, d_val, dh_val = 3, 3, 8, 32; np.random.seed(42)
W_OVs_L1 = np.random.randn(H1,d_val,d_val)*0.3
W_OVs_L2 = np.random.randn(H2,d_val,d_val)*0.3
W_enc_s = np.random.randn(d_val,dh_val); W_dec_s = np.random.randn(dh_val,d_val)
feat_dir = np.random.randn(d_val); feat_dir /= np.linalg.norm(feat_dir)
W_enc_s[:,5] = feat_dir*10; W_dec_s[5,:] = feat_dir
W_OVs_L1[0] = np.eye(d_val)*2; W_OVs_L2[1] = np.eye(d_val)*2.5
results = find_self_reinforcing(W_OVs_L1, W_OVs_L2, W_enc_s, W_dec_s, top_k=3)
h1, h2, feat, score = results[0]
check("planted h1=0 is top", h1, 0)
check("planted h2=1 is top", h2, 1)
check("planted feature=5 is top", feat, 5)
check("sorted descending", cond=lambda r: r[0][3] >= r[1][3] >= r[2][3], got=results)
# Out:
# ==================================================
# Q4 PART 4 TESTS (HARD)
# ==================================================
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[79], line 9
#       7 W_enc_s[:,5] = feat_dir*10; W_dec_s[5,:] = feat_dir
#       8 W_OVs_L1[0] = np.eye(d_val)*2; W_OVs_L2[1] = np.eye(d_val)*2.5
# ----> 9 results = find_self_reinforcing(W_OVs_L1, W_OVs_L2, W_enc_s, W_dec_s, top_k=3)
#      10 h1, h2, feat, score = results[0]
#      11 check("planted h1=0 is top", h1, 0)
#
# Cell In[77], line 121, in find_self_reinforcing(W_OVs_L1, W_OVs_L2, W_enc, W_dec, top_k)
#     104 def find_self_reinforcing(W_OVs_L1, W_OVs_L2, W_enc, W_dec, top_k=3):
#     105     """
#     106     Goal: Find SAE features that are heavily self-reinforced by a virtual attention head
#     107     spanning two layers. A feature self-reinforces if the virtual OV matrix maps its
#    (...)
#     119         sorted descending by the alignment_score.
#     120     """
# --> 121     raise NotImplementedError()
#
# NotImplementedError:
